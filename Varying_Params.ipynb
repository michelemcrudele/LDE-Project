# %%
import numpy as np
import matplotlib.pyplot as plt
from matplotlib import cm
import networkx as nx
import sys
from utils import SIR_net, SIR_net_adaptive

# %%
N = 1000 # number of nodes

ave_degree = 15

initial_infecteds = np.random.choice(np.arange(N), size=100, replace=False)

initial_no_vax = np.random.choice(np.arange(N), size=int(12/100*N), replace=False) #in italy novax = 12% population

BAG1 = nx.barabasi_albert_graph(N, ave_degree//2)

pro = 0.3        # rate of classical media influence on people
pol = 0.02       # propensity of opinion polarization
p_sym = 0.05     # prob for an infected person to have severe symptoms
r = 0.8         # rate of vaccination for PV

# %%
R0s = np.linspace(1.2, 3.5,  12) # sensible COVID-19 range
# beta = R0*mu

# %% [markdown]
# # SIMULATIONS

# %% [markdown]
# ### Here I fix mu and vary R0

# %%
mu = 0.1    # recovery rate

fig, ax = plt.subplots(nrows=3, ncols=4, figsize=(4*4, 3*3))
fig.tight_layout(h_pad = 4)
i = 0

for R0 in R0s:
    BAG2 = BAG1.copy()
    BAG3 = BAG2.copy()
    print('1 simulation:\n')
    sim1 = SIR_net(BAG1, beta = mu*R0, mu = mu, initial_infecteds = initial_infecteds)
    
    print('\n2 simulation:\n')
    sim2 = SIR_net_adaptive(BAG1, BAG2, beta = mu*R0, mu = mu, r = r, pro = pro, pol = pol, p_sym = p_sym, 
                            initial_infecteds = initial_infecteds, initial_no_vax=[])
    
    print('\n3 simulation:\n')
    sim3 = SIR_net_adaptive(BAG1, BAG3, beta = mu*R0, mu = mu, r = r, pro = pro, pol = pol, p_sym = p_sym, 
                            initial_infecteds = initial_infecteds, initial_no_vax = initial_no_vax)
    
    colors = cm.get_cmap('winter', 3)
    
    if i<=3:
        ax[0, i].plot(sim2[0], sim2[2], lw=3, c=colors(0), label= "0 No-Vax", alpha=0.6)
        ax[0, i].plot(sim3[0], sim3[2], lw=3, c=colors(1), label= "12% No-Vax", alpha=0.6)
        ax[0, i].plot(sim1[0], sim1[2], lw=3, c=colors(4), label= "SIR", alpha=0.6)
        ax[0, i].legend(fontsize=10)
        ax[0, i].set_title("R0 = %.2f"%R0)
        ax[0, i].set_ylabel("Prevalence", size=8)
        ax[0, i].set_xlabel("time", size=8)
        ax[0, i].set_xlim(0, 100)
        ax[0, i].set_ylim(0, 1000)

    elif i<=7:
        ax[1, i-4].plot(sim2[0], sim2[2], lw=3, c=colors(0), label= "0 No-Vax", alpha=0.6)
        ax[1, i-4].plot(sim3[0], sim3[2], lw=3, c=colors(1), label= "12% No-Vax", alpha=0.6)
        ax[1, i-4].plot(sim1[0], sim1[2], lw=3, c=colors(4), label= "SIR", alpha=0.6)
        ax[1, i-4].legend(fontsize=10)
        ax[1, i-4].set_title("R0 = %.2f"%R0)
        ax[1, i-4].set_ylabel("Prevalence", size=8)
        ax[1, i-4].set_xlabel("time", size=8)
        ax[1, i-4].set_xlim(0, 100)
        ax[1, i-4].set_ylim(0, 1000)
    
    else:
        ax[2, i-8].plot(sim2[0], sim2[2], lw=3, c=colors(0), label= "0 No-Vax", alpha=0.6)
        ax[2, i-8].plot(sim3[0], sim3[2], lw=3, c=colors(1), label= "12% No-Vax", alpha=0.6)
        ax[2, i-8].plot(sim1[0], sim1[2], lw=3, c=colors(4), label= "SIR", alpha=0.6)
        ax[2, i-8].legend(fontsize=10)
        ax[2, i-8].set_title("R0 = %.2f"%R0)
        ax[2, i-8].set_ylabel("Prevalence", size=8)
        ax[2, i-8].set_xlabel("time", size=8)
        ax[2, i-8].set_xlim(0, 100)
        ax[2, i-8].set_ylim(0, 1000)
    
    i += 1  
    
plt.show()
# Out:
# 1 simulation:
#
# simulation until time t=69
# 2 simulation:
#
# simulation until time t=68
# 3 simulation:
#
# 1 simulation:til time t=86
#
# simulation until time t=71
# 2 simulation:
#
# simulation until time t=78
# 3 simulation:
#
# 1 simulation:til time t=90
#
# simulation until time t=81
# 2 simulation:
#
# simulation until time t=76
# 3 simulation:
#
# 1 simulation:til time t=118
#
# simulation until time t=62
# 2 simulation:
#
# simulation until time t=63
# 3 simulation:
#
# 1 simulation:til time t=73
#
# simulation until time t=68
# 2 simulation:
#
# simulation until time t=65
# 3 simulation:
#
# 1 simulation:til time t=76
#
# simulation until time t=66
# 2 simulation:
#
# simulation until time t=64
# 3 simulation:
#
# 1 simulation:til time t=97
#
# simulation until time t=72
# 2 simulation:
#
# simulation until time t=85
# 3 simulation:
#
# 1 simulation:til time t=76
#
# simulation until time t=68
# 2 simulation:
#
# simulation until time t=65
# 3 simulation:
#
# ...

# %%
mu = 0.03  # recovery rate

fig, ax = plt.subplots(nrows=3, ncols=4, figsize=(4*4, 3*3))
fig.tight_layout(h_pad = 4)
i = 0

for R0 in R0s:
    BAG2 = BAG1.copy()
    BAG3 = BAG2.copy()
    
    print('1 simulation:\n')
    sim1 = SIR_net(BAG1, beta = mu*R0, mu = mu, initial_infecteds = initial_infecteds)
    
    print('\n2 simulation:\n')
    sim2 = SIR_net_adaptive(BAG1, BAG2, beta = mu*R0, mu = mu, r = r, pro = pro, pol = pol, p_sym = p_sym, 
                            initial_infecteds = initial_infecteds, initial_no_vax=[])
    
    print('\n3 simulation:\n')
    sim3 = SIR_net_adaptive(BAG1, BAG3, beta = mu*R0, mu = mu, r = r, pro = pro, pol = pol, p_sym = p_sym, 
                            initial_infecteds = initial_infecteds, initial_no_vax = initial_no_vax)
    
    colors = cm.get_cmap('winter', 3)
    
    if i<=3:
        ax[0, i].plot(sim2[0], sim2[2], lw=3, c=colors(0), label= "0 No-Vax", alpha=0.6)
        ax[0, i].plot(sim3[0], sim3[2], lw=3, c=colors(1), label= "12% No-Vax", alpha=0.6)
        ax[0, i].plot(sim1[0], sim1[2], lw=3, c=colors(4), label= "SIR", alpha=0.6)
        ax[0, i].legend(fontsize=10)
        ax[0, i].set_title("R0 = %.2f"%R0)
        ax[0, i].set_ylabel("Prevalence", size=8)
        ax[0, i].set_xlabel("time", size=8)
        ax[0, i].set_xlim(0, 200)
        ax[0, i].set_ylim(0, 1000)

    elif i<=7:
        ax[1, i-4].plot(sim2[0], sim2[2], lw=3, c=colors(0), label= "0 No-Vax", alpha=0.6)
        ax[1, i-4].plot(sim3[0], sim3[2], lw=3, c=colors(1), label= "12% No-Vax", alpha=0.6)
        ax[1, i-4].plot(sim1[0], sim1[2], lw=3, c=colors(4), label= "SIR", alpha=0.6)
        ax[1, i-4].legend(fontsize=10)
        ax[1, i-4].set_title("R0 = %.2f"%R0)
        ax[1, i-4].set_ylabel("Prevalence", size=8)
        ax[1, i-4].set_xlabel("time", size=8)
        ax[1, i-4].set_xlim(0, 200)
        ax[1, i-4].set_ylim(0, 1000)
    
    else:
        ax[2, i-8].plot(sim2[0], sim2[2], lw=3, c=colors(0), label= "0 No-Vax", alpha=0.6)
        ax[2, i-8].plot(sim3[0], sim3[2], lw=3, c=colors(1), label= "12% No-Vax", alpha=0.6)
        ax[2, i-8].plot(sim1[0], sim1[2], lw=3, c=colors(4), label= "SIR", alpha=0.6)
        ax[2, i-8].legend(fontsize=10)
        ax[2, i-8].set_title("R0 = %.2f"%R0)
        ax[2, i-8].set_ylabel("Prevalence", size=8)
        ax[2, i-8].set_xlabel("time", size=8)
        ax[2, i-8].set_xlim(0, 200)
        ax[2, i-8].set_ylim(0, 1000)
    
    i += 1  
    
plt.show()
# Out:
# 1 simulation:
#
# simulation until time t=217
# 2 simulation:
#
# simulation until time t=213
# 3 simulation:
#
# 1 simulation:til time t=374
#
# simulation until time t=242
# 2 simulation:
#
# simulation until time t=218
# 3 simulation:
#
# 1 simulation:til time t=202
#
# simulation until time t=241
# 2 simulation:
#
# simulation until time t=247
# 3 simulation:
#
# 1 simulation:til time t=203
#
# simulation until time t=212
# 2 simulation:
#
# simulation until time t=201
# 3 simulation:
#
# 1 simulation:til time t=219
#
# simulation until time t=239
# 2 simulation:
#
# simulation until time t=202
# 3 simulation:
#
# 1 simulation:til time t=249
#
# simulation until time t=288
# 2 simulation:
#
# simulation until time t=214
# 3 simulation:
#
# 1 simulation:til time t=251
#
# simulation until time t=373
# 2 simulation:
#
# simulation until time t=196
# 3 simulation:
#
# 1 simulation:til time t=287
#
# simulation until time t=274
# 2 simulation:
#
# simulation until time t=193
# ...

# %% [markdown]
# ### Here I fix mu and R0 and vary r

# %%
mu = 0.03
R0 = 2

rs = np.linspace(0.1, 1, 12)

fig, ax = plt.subplots(nrows=3, ncols=4, figsize=(4*4, 3*3))
fig.tight_layout(h_pad = 4)
i = 0

print('1 simulation:\n')
sim1 = SIR_net(BAG1, beta = mu*R0, mu = mu, initial_infecteds = initial_infecteds)

for R in rs:
    BAG2 = BAG1.copy()
    BAG3 = BAG2.copy()
    
    print('\n2 simulation:\n')
    sim2 = SIR_net_adaptive(BAG1, BAG2, beta = mu*R0, mu = mu, r = R, pro = pro, pol = pol, p_sym = p_sym, 
                            initial_infecteds = initial_infecteds, initial_no_vax=[])
    
    print('\n3 simulation:\n')
    sim3 = SIR_net_adaptive(BAG1, BAG3, beta = mu*R0, mu = mu, r = R, pro = pro, pol = pol, p_sym = p_sym, 
                            initial_infecteds = initial_infecteds, initial_no_vax = initial_no_vax)
    
    colors = cm.get_cmap('winter', 3)
    
    if i<=3:
        ax[0, i].plot(sim2[0], sim2[2], lw=3, c=colors(0), label= "0 No-Vax", alpha=0.6)
        ax[0, i].plot(sim3[0], sim3[2], lw=3, c=colors(1), label= "12% No-Vax", alpha=0.6)
        ax[0, i].plot(sim1[0], sim1[2], lw=3, c=colors(4), label= "SIR", alpha=0.6)
        ax[0, i].legend(fontsize=10)
        ax[0, i].set_title("Vaccination Rate = %.2f"%R)
        ax[0, i].set_ylabel("Prevalence", size=8)
        ax[0, i].set_xlabel("time", size=8)
        ax[0, i].set_xlim(0, 200)
        ax[0, i].set_ylim(0, 1000)

    elif i<=7:
        ax[1, i-4].plot(sim2[0], sim2[2], lw=3, c=colors(0), label= "0 No-Vax", alpha=0.6)
        ax[1, i-4].plot(sim3[0], sim3[2], lw=3, c=colors(1), label= "12% No-Vax", alpha=0.6)
        ax[1, i-4].plot(sim1[0], sim1[2], lw=3, c=colors(4), label= "SIR", alpha=0.6)
        ax[1, i-4].legend(fontsize=10)
        ax[1, i-4].set_title("Vaccination Rate = %.2f"%R)
        ax[1, i-4].set_ylabel("Prevalence", size=8)
        ax[1, i-4].set_xlabel("time", size=8)
        ax[1, i-4].set_xlim(0, 200)
        ax[1, i-4].set_ylim(0, 1000)
    
    else:
        ax[2, i-8].plot(sim2[0], sim2[2], lw=3, c=colors(0), label= "0 No-Vax", alpha=0.6)
        ax[2, i-8].plot(sim3[0], sim3[2], lw=3, c=colors(1), label= "12% No-Vax", alpha=0.6)
        ax[2, i-8].plot(sim1[0], sim1[2], lw=3, c=colors(4), label= "SIR", alpha=0.6)
        ax[2, i-8].legend(fontsize=10)
        ax[2, i-8].set_title("Vaccination Rate = %.2f"%R)
        ax[2, i-8].set_ylabel("Prevalence", size=8)
        ax[2, i-8].set_xlabel("time", size=8)
        ax[2, i-8].set_xlim(0, 200)
        ax[2, i-8].set_ylim(0, 1000)
    
    i += 1  
    
plt.show()
# Out:
# 1 simulation:
#
# simulation until time t=234
# 2 simulation:
#
# simulation until time t=239
# 3 simulation:
#
# simulation until time t=222
# 2 simulation:
#
# simulation until time t=215
# 3 simulation:
#
# simulation until time t=274
# 2 simulation:
#
# simulation until time t=221
# 3 simulation:
#
# simulation until time t=299
# 2 simulation:
#
# simulation until time t=232
# 3 simulation:
#
# simulation until time t=206
# 2 simulation:
#
# simulation until time t=231
# 3 simulation:
#
# simulation until time t=186
# 2 simulation:
#
# simulation until time t=256
# 3 simulation:
#
# simulation until time t=214
# 2 simulation:
#
# simulation until time t=256
# 3 simulation:
#
# simulation until time t=241
# 2 simulation:
#
# simulation until time t=185
# 3 simulation:
#
# simulation until time t=242
# 2 simulation:
#
# simulation until time t=259
# 3 simulation:
#
# simulation until time t=203
# 2 simulation:
#
# simulation until time t=207
# 3 simulation:
#
# ...

# %% [markdown]
# ### Here I vary the propensity of opinion polarization

# %%
mu = 0.03
R0 = 2
r = 0.8

pols = np.linspace(0.01, 0.5, 12)

fig, ax = plt.subplots(nrows=3, ncols=4, figsize=(4*4, 3*3))
fig.tight_layout(h_pad = 4)
i = 0

print('1 simulation:\n')
sim1 = SIR_net(BAG1, beta = mu*R0, mu = mu, initial_infecteds = initial_infecteds)

for p in pols:
    BAG2 = BAG1.copy()
    BAG3 = BAG2.copy()
    
    print('\n2 simulation:\n')
    sim2 = SIR_net_adaptive(BAG1, BAG2, beta = mu*R0, mu = mu, r = r, pro = pro, pol = p, p_sym = p_sym, 
                            initial_infecteds = initial_infecteds, initial_no_vax=[])
    
    print('\n3 simulation:\n')
    sim3 = SIR_net_adaptive(BAG1, BAG3, beta = mu*R0, mu = mu, r = r, pro = pro, pol = p, p_sym = p_sym, 
                            initial_infecteds = initial_infecteds, initial_no_vax = initial_no_vax)
    
    colors = cm.get_cmap('winter', 3)
    
    if i<=3:
        ax[0, i].plot(sim2[0], sim2[2], lw=3, c=colors(0), label= "0 No-Vax", alpha=0.6)
        ax[0, i].plot(sim3[0], sim3[2], lw=3, c=colors(1), label= "12% No-Vax", alpha=0.6)
        ax[0, i].plot(sim1[0], sim1[2], lw=3, c=colors(4), label= "SIR", alpha=0.6)
        ax[0, i].legend(fontsize=10)
        ax[0, i].set_title("Polarization = %.2f"%p)
        ax[0, i].set_ylabel("Prevalence", size=8)
        ax[0, i].set_xlabel("time", size=8)
        ax[0, i].set_xlim(0, 200)
        ax[0, i].set_ylim(0, 1000)

    elif i<=7:
        ax[1, i-4].plot(sim2[0], sim2[2], lw=3, c=colors(0), label= "0 No-Vax", alpha=0.6)
        ax[1, i-4].plot(sim3[0], sim3[2], lw=3, c=colors(1), label= "12% No-Vax", alpha=0.6)
        ax[1, i-4].plot(sim1[0], sim1[2], lw=3, c=colors(4), label= "SIR", alpha=0.6)
        ax[1, i-4].legend(fontsize=10)
        ax[1, i-4].set_title("Polarization = %.2f"%p)
        ax[1, i-4].set_ylabel("Prevalence", size=8)
        ax[1, i-4].set_xlabel("time", size=8)
        ax[1, i-4].set_xlim(0, 200)
        ax[1, i-4].set_ylim(0, 1000)
    
    else:
        ax[2, i-8].plot(sim2[0], sim2[2], lw=3, c=colors(0), label= "0 No-Vax", alpha=0.6)
        ax[2, i-8].plot(sim3[0], sim3[2], lw=3, c=colors(1), label= "12% No-Vax", alpha=0.6)
        ax[2, i-8].plot(sim1[0], sim1[2], lw=3, c=colors(4), label= "SIR", alpha=0.6)
        ax[2, i-8].legend(fontsize=10)
        ax[2, i-8].set_title("Polarization = %.2f"%p)
        ax[2, i-8].set_ylabel("Prevalence", size=8)
        ax[2, i-8].set_xlabel("time", size=8)
        ax[2, i-8].set_xlim(0, 200)
        ax[2, i-8].set_ylim(0, 1000)
    
    i += 1  
    
plt.show()
# Out:
# 1 simulation:
#
# simulation until time t=218
# 2 simulation:
#
# simulation until time t=207
# 3 simulation:
#
# simulation until time t=197
# 2 simulation:
#
# simulation until time t=219
# 3 simulation:
#
# simulation until time t=360
# 2 simulation:
#
# simulation until time t=258
# 3 simulation:
#
# simulation until time t=345
# 2 simulation:
#
# simulation until time t=159
# 3 simulation:
#
# simulation until time t=216
# 2 simulation:
#
# simulation until time t=302
# 3 simulation:
#
# simulation until time t=240
# 2 simulation:
#
# simulation until time t=229
# 3 simulation:
#
# simulation until time t=228
# 2 simulation:
#
# simulation until time t=219
# 3 simulation:
#
# simulation until time t=226
# 2 simulation:
#
# simulation until time t=206
# 3 simulation:
#
# simulation until time t=184
# 2 simulation:
#
# simulation until time t=201
# 3 simulation:
#
# simulation until time t=196
# 2 simulation:
#
# simulation until time t=266
# 3 simulation:
#
# ...

# %% [markdown]
# ### Here I vary the rate of classical media influence on people

# %%
mu = 0.03
R0 = 2
r = 0.8
pol = 0.02

pros = np.linspace(0.01, 0.8, 12)

fig, ax = plt.subplots(nrows=3, ncols=4, figsize=(4*4, 3*3))
fig.tight_layout(h_pad = 4)
i = 0

print('1 simulation:\n')
sim1 = SIR_net(BAG1, beta = mu*R0, mu = mu, initial_infecteds = initial_infecteds)

for pr in pros:
    BAG2 = BAG1.copy()
    BAG3 = BAG2.copy()
    
    print('\n2 simulation:\n')
    sim2 = SIR_net_adaptive(BAG1, BAG2, beta = mu*R0, mu = mu, r = r, pro = pr, pol = pol, p_sym = p_sym, 
                            initial_infecteds = initial_infecteds, initial_no_vax=[])
    
    print('\n3 simulation:\n')
    sim3 = SIR_net_adaptive(BAG1, BAG3, beta = mu*R0, mu = mu, r = r, pro = pr, pol = pol, p_sym = p_sym, 
                            initial_infecteds = initial_infecteds, initial_no_vax = initial_no_vax)
    
    colors = cm.get_cmap('winter', 3)
    
    if i<=3:
        ax[0, i].plot(sim2[0], sim2[2], lw=3, c=colors(0), label= "0 No-Vax", alpha=0.6)
        ax[0, i].plot(sim3[0], sim3[2], lw=3, c=colors(1), label= "12% No-Vax", alpha=0.6)
        ax[0, i].plot(sim1[0], sim1[2], lw=3, c=colors(4), label= "SIR", alpha=0.6)
        ax[0, i].legend(fontsize=10)
        ax[0, i].set_title("Rate of Media = %.2f"%pr)
        ax[0, i].set_ylabel("Prevalence", size=8)
        ax[0, i].set_xlabel("time", size=8)
        ax[0, i].set_xlim(0, 200)
        ax[0, i].set_ylim(0, 1000)

    elif i<=7:
        ax[1, i-4].plot(sim2[0], sim2[2], lw=3, c=colors(0), label= "0 No-Vax", alpha=0.6)
        ax[1, i-4].plot(sim3[0], sim3[2], lw=3, c=colors(1), label= "12% No-Vax", alpha=0.6)
        ax[1, i-4].plot(sim1[0], sim1[2], lw=3, c=colors(4), label= "SIR", alpha=0.6)
        ax[1, i-4].legend(fontsize=10)
        ax[1, i-4].set_title("Rate of Media = %.2f"%pr)
        ax[1, i-4].set_ylabel("Prevalence", size=8)
        ax[1, i-4].set_xlabel("time", size=8)
        ax[1, i-4].set_xlim(0, 200)
        ax[1, i-4].set_ylim(0, 1000)
    
    else:
        ax[2, i-8].plot(sim2[0], sim2[2], lw=3, c=colors(0), label= "0 No-Vax", alpha=0.6)
        ax[2, i-8].plot(sim3[0], sim3[2], lw=3, c=colors(1), label= "12% No-Vax", alpha=0.6)
        ax[2, i-8].plot(sim1[0], sim1[2], lw=3, c=colors(4), label= "SIR", alpha=0.6)
        ax[2, i-8].legend(fontsize=10)
        ax[2, i-8].set_title("Rate of Media = %.2f"%pr)
        ax[2, i-8].set_ylabel("Prevalence", size=8)
        ax[2, i-8].set_xlabel("time", size=8)
        ax[2, i-8].set_xlim(0, 200)
        ax[2, i-8].set_ylim(0, 1000)
    
    i += 1  
    
plt.show()
# Out:
# 1 simulation:
#
# simulation until time t=286
# 2 simulation:
#
# simulation until time t=237
# 3 simulation:
#
# simulation until time t=242
# 2 simulation:
#
# simulation until time t=157
# 3 simulation:
#
# simulation until time t=281
# 2 simulation:
#
# simulation until time t=326
# 3 simulation:
#
# simulation until time t=223
# 2 simulation:
#
# simulation until time t=214
# 3 simulation:
#
# simulation until time t=270
# 2 simulation:
#
# simulation until time t=218
# 3 simulation:
#
# simulation until time t=202
# 2 simulation:
#
# simulation until time t=261
# 3 simulation:
#
# simulation until time t=178
# 2 simulation:
#
# simulation until time t=266
# 3 simulation:
#
# simulation until time t=210
# 2 simulation:
#
# simulation until time t=190
# 3 simulation:
#
# simulation until time t=200
# 2 simulation:
#
# simulation until time t=194
# 3 simulation:
#
# simulation until time t=386
# 2 simulation:
#
# simulation until time t=221
# 3 simulation:
#
# ...

# %% [markdown]
# ### Here I vary the probability for an infected to have severe symptoms

# %%
mu = 0.03
R0 = 2
r = 0.8
pol = 0.02
pro = 0.3

p_syms = np.linspace(0.01, 0.5, 12)

fig, ax = plt.subplots(nrows=3, ncols=4, figsize=(4*4, 3*3))
fig.tight_layout(h_pad = 4)
i = 0

print('1 simulation:\n')
sim1 = SIR_net(BAG1, beta = mu*R0, mu = mu, initial_infecteds = initial_infecteds)

for ps in p_syms:
    BAG2 = BAG1.copy()
    BAG3 = BAG2.copy()
    
    print('\n2 simulation:\n')
    sim2 = SIR_net_adaptive(BAG1, BAG2, beta = mu*R0, mu = mu, r = r, pro = pro, pol = pol, p_sym = ps, 
                            initial_infecteds = initial_infecteds, initial_no_vax=[])
    
    print('\n3 simulation:\n')
    sim3 = SIR_net_adaptive(BAG1, BAG3, beta = mu*R0, mu = mu, r = r, pro = pro, pol = pol, p_sym = ps, 
                            initial_infecteds = initial_infecteds, initial_no_vax = initial_no_vax)
    
    colors = cm.get_cmap('winter', 3)
    
    if i<=3:
        ax[0, i].plot(sim2[0], sim2[2], lw=3, c=colors(0), label= "0 No-Vax", alpha=0.6)
        ax[0, i].plot(sim3[0], sim3[2], lw=3, c=colors(1), label= "12% No-Vax", alpha=0.6)
        ax[0, i].plot(sim1[0], sim1[2], lw=3, c=colors(4), label= "SIR", alpha=0.6)
        ax[0, i].legend(fontsize=10)
        ax[0, i].set_title("Rate of Severe Symptoms = %.2f"%ps)
        ax[0, i].set_ylabel("Prevalence", size=8)
        ax[0, i].set_xlabel("time", size=8)
        ax[0, i].set_xlim(0, 200)
        ax[0, i].set_ylim(0, 1000)

    elif i<=7:
        ax[1, i-4].plot(sim2[0], sim2[2], lw=3, c=colors(0), label= "0 No-Vax", alpha=0.6)
        ax[1, i-4].plot(sim3[0], sim3[2], lw=3, c=colors(1), label= "12% No-Vax", alpha=0.6)
        ax[1, i-4].plot(sim1[0], sim1[2], lw=3, c=colors(4), label= "SIR", alpha=0.6)
        ax[1, i-4].legend(fontsize=10)
        ax[1, i-4].set_title("Rate of Severe Symptoms = %.2f"%ps)
        ax[1, i-4].set_ylabel("Prevalence", size=8)
        ax[1, i-4].set_xlabel("time", size=8)
        ax[1, i-4].set_xlim(0, 200)
        ax[1, i-4].set_ylim(0, 1000)
    
    else:
        ax[2, i-8].plot(sim2[0], sim2[2], lw=3, c=colors(0), label= "0 No-Vax", alpha=0.6)
        ax[2, i-8].plot(sim3[0], sim3[2], lw=3, c=colors(1), label= "12% No-Vax", alpha=0.6)
        ax[2, i-8].plot(sim1[0], sim1[2], lw=3, c=colors(4), label= "SIR", alpha=0.6)
        ax[2, i-8].legend(fontsize=10)
        ax[2, i-8].set_title("Rate of Severe Symptoms = %.2f"%ps)
        ax[2, i-8].set_ylabel("Prevalence", size=8)
        ax[2, i-8].set_xlabel("time", size=8)
        ax[2, i-8].set_xlim(0, 200)
        ax[2, i-8].set_ylim(0, 1000)
    
    i += 1  
    
plt.show()
# Out:
# 1 simulation:
#
# simulation until time t=288
# 2 simulation:
#
# simulation until time t=284
# 3 simulation:
#
# simulation until time t=225
# 2 simulation:
#
# simulation until time t=189
# 3 simulation:
#
# simulation until time t=216
# 2 simulation:
#
# simulation until time t=174
# 3 simulation:
#
# simulation until time t=197
# 2 simulation:
#
# simulation until time t=173
# 3 simulation:
#
# simulation until time t=265
# 2 simulation:
#
# simulation until time t=208
# 3 simulation:
#
# simulation until time t=273
# 2 simulation:
#
# simulation until time t=171
# 3 simulation:
#
# simulation until time t=191
# 2 simulation:
#
# simulation until time t=240
# 3 simulation:
#
# simulation until time t=306
# 2 simulation:
#
# simulation until time t=214
# 3 simulation:
#
# simulation until time t=247
# 2 simulation:
#
# simulation until time t=176
# 3 simulation:
#
# simulation until time t=262
# 2 simulation:
#
# simulation until time t=206
# 3 simulation:
#
# ...

# %%
# colors = cm.get_cmap('winter', 3)
# fig, ax = plt.subplots(nrows=1, ncols=1, figsize=(4, 3))
# ax.plot(sim2[0], sim2[2], lw=3, c=colors(0), label= "0 No-Vax", alpha=0.6)
# ax.plot(sim3[0], sim3[2], lw=3, c=colors(1), label= "50 No-Vax", alpha=0.6)
# ax.plot(sim1[0], sim1[2], lw=3, c=colors(4), label= "SIR", alpha=0.6)
# ax.legend(fontsize=10)
# ax.set_title(f"R0 =")
# ax.set_ylabel("Prevalence", size=8)
# ax.set_xlabel("Time", size=8)
# ax.set_xlim(0, 100)
# ax.set_ylim(0, 1000)
# plt.show()

# %%
# #nx.draw(BAG3)
# n_novax = 0
# n_provax = 0
# n_neutral = 0
# for i, data in BAG3.nodes(data=True):
#     if data['aware_status'] == 1:
#         n_novax += 1
#     elif data['aware_status'] == 2:
#         n_provax += 1
#     else:
#         n_neutral += 1

# print('no-vax number:', n_novax)
# print('pro-vax number:', n_provax)
# print('neutral:', n_neutral)
